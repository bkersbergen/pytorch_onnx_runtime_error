# %%
import torch
from torch import nn
import onnx
import onnxruntime as ort

from model import COREModel

# %%
import sys
print(sys.version)
print(torch.__version__)
# Out:
# 3.9.6 (default, Oct 18 2022, 12:41:40)
# [Clang 14.0.0 (clang-1400.0.29.202)]
# 1.13.1

# %%
x_train = torch.ones([1,2], dtype=torch.long)

# %% [markdown]
# ### Load big model that uses a torch.tril function

# %%
model = COREModel()
model.eval()
print(model.forward(x_train))
# Out:
# tensor([[ 2.2729, 14.2857,  1.7739,  0.5872, -1.4148]], grad_fn=<DivBackward0>)

# %% [markdown]
# # Export big model in onnx format to disk

# %%
bigmodel_onnx_filename = 'bigmodel.onnx'
torch.onnx.export(
    model,
    x_train,
    bigmodel_onnx_filename,
    input_names=['x'],
    output_names=['output'],
)
# Out:
# /Users/bkersbergen/git/pytorch_onnx_error/venv/lib/python3.9/site-packages/torch/onnx/_internal/jit_utils.py:258: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1888.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /Users/bkersbergen/git/pytorch_onnx_error/venv/lib/python3.9/site-packages/torch/onnx/utils.py:687: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1888.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /Users/bkersbergen/git/pytorch_onnx_error/venv/lib/python3.9/site-packages/torch/onnx/utils.py:1178: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1888.)
#   _C._jit_pass_onnx_graph_shape_type_inference(

# %% [markdown]
# ### Print the Onnx Nodes in the big model. Confirming it contains Trilu nodes

# %%
onnx.load(bigmodel_onnx_filename)
# Out:
# ir_version: 7
# producer_name: "pytorch"
# producer_version: "1.13.1"
# graph {
#   node {
#     output: "/item_embedding/Constant_output_0"
#     name: "/item_embedding/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 7
#         raw_data: "\000\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "item_embedding.weight"
#     input: "x"
#     output: "/item_embedding/Gather_output_0"
#     name: "/item_embedding/Gather"
#     op_type: "Gather"
#   }
#   node {
#     output: "/net/Constant_output_0"
#     name: "/net/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 7
#         raw_data: "\000\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "x"
#     input: "/net/Constant_output_0"
#     output: "/net/Greater_output_0"
#     name: "/net/Greater"
#     op_type: "Greater"
#   }
#   node {
#     output: "/net/Constant_1_output_0"
#     name: "/net/Constant_1"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 2
#         data_type: 7
#         raw_data: "\000\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "x"
#     output: "/net/Shape_output_0"
#     name: "/net/Shape"
#     op_type: "Shape"
#   }
#   node {
#     input: "/net/Constant_1_output_0"
#     input: "/net/Shape_output_0"
#     output: "/net/Expand_output_0"
#     name: "/net/Expand"
#     op_type: "Expand"
#   }
#   node {
#     input: "net.position_embedding.weight"
#     input: "/net/Expand_output_0"
#     output: "/net/position_embedding/Gather_output_0"
#     name: "/net/position_embedding/Gather"
#     op_type: "Gather"
#   }
#   node {
#     input: "/item_embedding/Gather_output_0"
#     input: "/net/position_embedding/Gather_output_0"
#     output: "/net/Add_output_0"
#     name: "/net/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/Add_output_0"
#     output: "/net/LayerNorm/ReduceMean_output_0"
#     name: "/net/LayerNorm/ReduceMean"
#     op_type: "ReduceMean"
#     attribute {
#       name: "axes"
#       ints: -1
#       type: INTS
#     }
#   }
#   node {
#     input: "/net/Add_output_0"
#     input: "/net/LayerNorm/ReduceMean_output_0"
#     output: "/net/LayerNorm/Sub_output_0"
#     name: "/net/LayerNorm/Sub"
#     op_type: "Sub"
#   }
#   node {
#     output: "/net/LayerNorm/Constant_output_0"
#     name: "/net/LayerNorm/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\000\000\000@"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/LayerNorm/Sub_output_0"
#     input: "/net/LayerNorm/Constant_output_0"
#     output: "/net/LayerNorm/Pow_output_0"
#     name: "/net/LayerNorm/Pow"
#     op_type: "Pow"
#   }
#   node {
#     input: "/net/LayerNorm/Pow_output_0"
#     output: "/net/LayerNorm/ReduceMean_1_output_0"
#     name: "/net/LayerNorm/ReduceMean_1"
#     op_type: "ReduceMean"
#     attribute {
#       name: "axes"
#       ints: -1
#       type: INTS
#     }
#   }
#   node {
#     output: "/net/LayerNorm/Constant_1_output_0"
#     name: "/net/LayerNorm/Constant_1"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\314\274\214+"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/LayerNorm/ReduceMean_1_output_0"
#     input: "/net/LayerNorm/Constant_1_output_0"
#     output: "/net/LayerNorm/Add_output_0"
#     name: "/net/LayerNorm/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/LayerNorm/Add_output_0"
#     output: "/net/LayerNorm/Sqrt_output_0"
#     name: "/net/LayerNorm/Sqrt"
#     op_type: "Sqrt"
#   }
#   node {
#     input: "/net/LayerNorm/Sub_output_0"
#     input: "/net/LayerNorm/Sqrt_output_0"
#     output: "/net/LayerNorm/Div_output_0"
#     name: "/net/LayerNorm/Div"
#     op_type: "Div"
#   }
#   node {
#     input: "/net/LayerNorm/Div_output_0"
#     input: "net.LayerNorm.weight"
#     output: "/net/LayerNorm/Mul_output_0"
#     name: "/net/LayerNorm/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/net/LayerNorm/Mul_output_0"
#     input: "net.LayerNorm.bias"
#     output: "/net/LayerNorm/Add_1_output_0"
#     name: "/net/LayerNorm/Add_1"
#     op_type: "Add"
#   }
#   node {
#     output: "/net/Constant_2_output_0"
#     name: "/net/Constant_2"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 7
#         raw_data: "\000\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "x"
#     input: "/net/Constant_2_output_0"
#     output: "/net/Equal_output_0"
#     name: "/net/Equal"
#     op_type: "Equal"
#   }
#   node {
#     input: "/net/Equal_output_0"
#     output: "/net/Not_output_0"
#     name: "/net/Not"
#     op_type: "Not"
#   }
#   node {
#     output: "/net/Constant_3_output_0"
#     name: "/net/Constant_3"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 1
#         data_type: 7
#         raw_data: "\001\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/Not_output_0"
#     input: "/net/Constant_3_output_0"
#     output: "/net/Unsqueeze_output_0"
#     name: "/net/Unsqueeze"
#     op_type: "Unsqueeze"
#   }
#   node {
#     output: "/net/Constant_4_output_0"
#     name: "/net/Constant_4"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 1
#         data_type: 7
#         raw_data: "\002\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/Unsqueeze_output_0"
#     input: "/net/Constant_4_output_0"
#     output: "/net/Unsqueeze_1_output_0"
#     name: "/net/Unsqueeze_1"
#     op_type: "Unsqueeze"
#   }
#   node {
#     output: "/net/Constant_5_output_0"
#     name: "/net/Constant_5"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 4
#         data_type: 7
#         raw_data: "\377\377\377\377\377\377\377\377\377\377\377\377\377\377\377\377\002\000\000\000\000\000\000\000\377\377\377\377\377\377\377\377"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     output: "/net/Constant_6_output_0"
#     name: "/net/Constant_6"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 1
#         data_type: 7
#         raw_data: "\004\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/Constant_6_output_0"
#     output: "/net/ConstantOfShape_output_0"
#     name: "/net/ConstantOfShape"
#     op_type: "ConstantOfShape"
#     attribute {
#       name: "value"
#       t {
#         dims: 1
#         data_type: 7
#         raw_data: "\001\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     output: "/net/Constant_7_output_0"
#     name: "/net/Constant_7"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 7
#         raw_data: "\377\377\377\377\377\377\377\377"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/ConstantOfShape_output_0"
#     input: "/net/Constant_7_output_0"
#     output: "/net/Mul_output_0"
#     name: "/net/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/net/Constant_5_output_0"
#     input: "/net/Mul_output_0"
#     output: "/net/Equal_1_output_0"
#     name: "/net/Equal_1"
#     op_type: "Equal"
#   }
#   node {
#     input: "/net/Equal_1_output_0"
#     input: "/net/ConstantOfShape_output_0"
#     input: "/net/Constant_5_output_0"
#     output: "/net/Where_output_0"
#     name: "/net/Where"
#     op_type: "Where"
#   }
#   node {
#     input: "/net/Unsqueeze_1_output_0"
#     input: "/net/Where_output_0"
#     output: "/net/Expand_1_output_0"
#     name: "/net/Expand_1"
#     op_type: "Expand"
#   }
#   node {
#     input: "/net/Expand_1_output_0"
#     input: "/item_embedding/Constant_output_0"
#     output: "/net/Trilu_output_0"
#     name: "/net/Trilu"
#     op_type: "Trilu"
#     attribute {
#       name: "upper"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     output: "/net/Constant_8_output_0"
#     name: "/net/Constant_8"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 11
#         raw_data: "\000\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     output: "/net/Constant_9_output_0"
#     name: "/net/Constant_9"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 11
#         raw_data: "\000\000\000\000\000\210\303\300"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/Trilu_output_0"
#     input: "/net/Constant_8_output_0"
#     input: "/net/Constant_9_output_0"
#     output: "/net/Where_1_output_0"
#     name: "/net/Where_1"
#     op_type: "Where"
#   }
#   node {
#     input: "/net/LayerNorm/Add_1_output_0"
#     input: "onnx::MatMul_352"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/query/MatMul_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/query/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.0.multi_head_attention.query.bias"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/query/MatMul_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/query/Add_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/query/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/LayerNorm/Add_1_output_0"
#     input: "onnx::MatMul_353"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/key/MatMul_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/key/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.0.multi_head_attention.key.bias"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/key/MatMul_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/key/Add_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/key/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/LayerNorm/Add_1_output_0"
#     input: "onnx::MatMul_354"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/value/MatMul_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/value/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.0.multi_head_attention.value.bias"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/value/MatMul_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/value/Add_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/value/Add"
#     op_type: "Add"
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Constant_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 4
#         data_type: 7
#         raw_data: "\001\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000 \000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/query/Add_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Constant_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Reshape"
#     op_type: "Reshape"
#     attribute {
#       name: "allowzero"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Transpose"
#     op_type: "Transpose"
#     attribute {
#       name: "perm"
#       ints: 0
#       ints: 2
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Constant_1_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Constant_1"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 4
#         data_type: 7
#         raw_data: "\001\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000 \000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/key/Add_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Constant_1_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_1_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_1"
#     op_type: "Reshape"
#     attribute {
#       name: "allowzero"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_1_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_1_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_1"
#     op_type: "Transpose"
#     attribute {
#       name: "perm"
#       ints: 0
#       ints: 2
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Constant_2_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Constant_2"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 4
#         data_type: 7
#         raw_data: "\001\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000 \000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/value/Add_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Constant_2_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_2_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_2"
#     op_type: "Reshape"
#     attribute {
#       name: "allowzero"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_2_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_2_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_2"
#     op_type: "Transpose"
#     attribute {
#       name: "perm"
#       ints: 0
#       ints: 2
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_1_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/MatMul_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Constant_3_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Constant_3"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\363\004\265@"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/MatMul_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Constant_3_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Div_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Div"
#     op_type: "Div"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Div_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Cast_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Cast"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 11
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Cast_output_0"
#     input: "/net/Where_1_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Add_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Add_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/softmax/Softmax_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/softmax/Softmax"
#     op_type: "Softmax"
#     attribute {
#       name: "axis"
#       i: -1
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/softmax/Softmax_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Cast_1_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Cast_1"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 11
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_2_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Cast_2_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Cast_2"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 11
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Cast_1_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Cast_2_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/MatMul_1_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/MatMul_1"
#     op_type: "MatMul"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/MatMul_1_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Cast_3_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Cast_3"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 1
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Cast_3_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_3_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_3"
#     op_type: "Transpose"
#     attribute {
#       name: "perm"
#       ints: 0
#       ints: 2
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Constant_4_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Constant_4"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 3
#         data_type: 7
#         raw_data: "\001\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000@\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Transpose_3_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Constant_4_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_3_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_3"
#     op_type: "Reshape"
#     attribute {
#       name: "allowzero"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Reshape_3_output_0"
#     input: "onnx::MatMul_374"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/dense/MatMul_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/dense/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.0.multi_head_attention.dense.bias"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/dense/MatMul_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/dense/Add_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/dense/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/dense/Add_output_0"
#     input: "/net/LayerNorm/Add_1_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/Add_1_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/Add_1"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Add_1_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/ReduceMean_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/ReduceMean"
#     op_type: "ReduceMean"
#     attribute {
#       name: "axes"
#       ints: -1
#       type: INTS
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/Add_1_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/ReduceMean_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Sub_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Sub"
#     op_type: "Sub"
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Constant_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\000\000\000@"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Sub_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Constant_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Pow_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Pow"
#     op_type: "Pow"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Pow_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/ReduceMean_1_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/ReduceMean_1"
#     op_type: "ReduceMean"
#     attribute {
#       name: "axes"
#       ints: -1
#       type: INTS
#     }
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Constant_1_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Constant_1"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\314\274\214+"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/ReduceMean_1_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Constant_1_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Add_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Add_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Sqrt_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Sqrt"
#     op_type: "Sqrt"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Sub_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Sqrt_output_0"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Div_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Div"
#     op_type: "Div"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Div_output_0"
#     input: "net.trm_encoder.layer.0.multi_head_attention.LayerNorm.weight"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Mul_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Mul_output_0"
#     input: "net.trm_encoder.layer.0.multi_head_attention.LayerNorm.bias"
#     output: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Add_1_output_0"
#     name: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Add_1"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Add_1_output_0"
#     input: "onnx::MatMul_375"
#     output: "/net/trm_encoder/layer.0/feed_forward/dense_1/MatMul_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/dense_1/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.0.feed_forward.dense_1.bias"
#     input: "/net/trm_encoder/layer.0/feed_forward/dense_1/MatMul_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/dense_1/Add_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/dense_1/Add"
#     op_type: "Add"
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/feed_forward/Constant_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\000\000\000?"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/dense_1/Add_output_0"
#     input: "/net/trm_encoder/layer.0/feed_forward/Constant_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/Mul_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/Mul"
#     op_type: "Mul"
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/feed_forward/Constant_1_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/Constant_1"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\363\004\265?"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/dense_1/Add_output_0"
#     input: "/net/trm_encoder/layer.0/feed_forward/Constant_1_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/Div_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/Div"
#     op_type: "Div"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/Div_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/Erf_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/Erf"
#     op_type: "Erf"
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/feed_forward/Constant_2_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/Constant_2"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\000\000\200?"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/Erf_output_0"
#     input: "/net/trm_encoder/layer.0/feed_forward/Constant_2_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/Add_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/Mul_output_0"
#     input: "/net/trm_encoder/layer.0/feed_forward/Add_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/Mul_1_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/Mul_1"
#     op_type: "Mul"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/Mul_1_output_0"
#     input: "onnx::MatMul_376"
#     output: "/net/trm_encoder/layer.0/feed_forward/dense_2/MatMul_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/dense_2/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.0.feed_forward.dense_2.bias"
#     input: "/net/trm_encoder/layer.0/feed_forward/dense_2/MatMul_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/dense_2/Add_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/dense_2/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/dense_2/Add_output_0"
#     input: "/net/trm_encoder/layer.0/multi_head_attention/LayerNorm/Add_1_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/Add_1_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/Add_1"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/Add_1_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/ReduceMean_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/ReduceMean"
#     op_type: "ReduceMean"
#     attribute {
#       name: "axes"
#       ints: -1
#       type: INTS
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/Add_1_output_0"
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/ReduceMean_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Sub_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Sub"
#     op_type: "Sub"
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Constant_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\000\000\000@"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Sub_output_0"
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Constant_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Pow_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Pow"
#     op_type: "Pow"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Pow_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/ReduceMean_1_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/ReduceMean_1"
#     op_type: "ReduceMean"
#     attribute {
#       name: "axes"
#       ints: -1
#       type: INTS
#     }
#   }
#   node {
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Constant_1_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Constant_1"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\314\274\214+"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/ReduceMean_1_output_0"
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Constant_1_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Add_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Add_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Sqrt_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Sqrt"
#     op_type: "Sqrt"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Sub_output_0"
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Sqrt_output_0"
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Div_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Div"
#     op_type: "Div"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Div_output_0"
#     input: "net.trm_encoder.layer.0.feed_forward.LayerNorm.weight"
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Mul_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Mul_output_0"
#     input: "net.trm_encoder.layer.0.feed_forward.LayerNorm.bias"
#     output: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Add_1_output_0"
#     name: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Add_1"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Add_1_output_0"
#     input: "onnx::MatMul_377"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/query/MatMul_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/query/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.1.multi_head_attention.query.bias"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/query/MatMul_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/query/Add_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/query/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Add_1_output_0"
#     input: "onnx::MatMul_378"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/key/MatMul_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/key/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.1.multi_head_attention.key.bias"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/key/MatMul_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/key/Add_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/key/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Add_1_output_0"
#     input: "onnx::MatMul_379"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/value/MatMul_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/value/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.1.multi_head_attention.value.bias"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/value/MatMul_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/value/Add_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/value/Add"
#     op_type: "Add"
#   }
#   node {
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Constant_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 4
#         data_type: 7
#         raw_data: "\001\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000 \000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/query/Add_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Constant_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Reshape"
#     op_type: "Reshape"
#     attribute {
#       name: "allowzero"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Transpose"
#     op_type: "Transpose"
#     attribute {
#       name: "perm"
#       ints: 0
#       ints: 2
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#   }
#   node {
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Constant_1_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Constant_1"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 4
#         data_type: 7
#         raw_data: "\001\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000 \000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/key/Add_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Constant_1_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_1_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_1"
#     op_type: "Reshape"
#     attribute {
#       name: "allowzero"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_1_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_1_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_1"
#     op_type: "Transpose"
#     attribute {
#       name: "perm"
#       ints: 0
#       ints: 2
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Constant_2_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Constant_2"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 4
#         data_type: 7
#         raw_data: "\001\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000 \000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/value/Add_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Constant_2_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_2_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_2"
#     op_type: "Reshape"
#     attribute {
#       name: "allowzero"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_2_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_2_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_2"
#     op_type: "Transpose"
#     attribute {
#       name: "perm"
#       ints: 0
#       ints: 2
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_1_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/MatMul_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Constant_3_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Constant_3"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\363\004\265@"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/MatMul_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Constant_3_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Div_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Div"
#     op_type: "Div"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Div_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Cast_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Cast"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 11
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Cast_output_0"
#     input: "/net/Where_1_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Add_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Add_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/softmax/Softmax_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/softmax/Softmax"
#     op_type: "Softmax"
#     attribute {
#       name: "axis"
#       i: -1
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/softmax/Softmax_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Cast_1_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Cast_1"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 11
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_2_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Cast_2_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Cast_2"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 11
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Cast_1_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Cast_2_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/MatMul_1_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/MatMul_1"
#     op_type: "MatMul"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/MatMul_1_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Cast_3_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Cast_3"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 1
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Cast_3_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_3_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_3"
#     op_type: "Transpose"
#     attribute {
#       name: "perm"
#       ints: 0
#       ints: 2
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#   }
#   node {
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Constant_4_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Constant_4"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 3
#         data_type: 7
#         raw_data: "\001\000\000\000\000\000\000\000\002\000\000\000\000\000\000\000@\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Transpose_3_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Constant_4_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_3_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_3"
#     op_type: "Reshape"
#     attribute {
#       name: "allowzero"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Reshape_3_output_0"
#     input: "onnx::MatMul_399"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/dense/MatMul_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/dense/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.1.multi_head_attention.dense.bias"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/dense/MatMul_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/dense/Add_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/dense/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/dense/Add_output_0"
#     input: "/net/trm_encoder/layer.0/feed_forward/LayerNorm/Add_1_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/Add_1_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/Add_1"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Add_1_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/ReduceMean_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/ReduceMean"
#     op_type: "ReduceMean"
#     attribute {
#       name: "axes"
#       ints: -1
#       type: INTS
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/Add_1_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/ReduceMean_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Sub_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Sub"
#     op_type: "Sub"
#   }
#   node {
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Constant_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\000\000\000@"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Sub_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Constant_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Pow_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Pow"
#     op_type: "Pow"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Pow_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/ReduceMean_1_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/ReduceMean_1"
#     op_type: "ReduceMean"
#     attribute {
#       name: "axes"
#       ints: -1
#       type: INTS
#     }
#   }
#   node {
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Constant_1_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Constant_1"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\314\274\214+"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/ReduceMean_1_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Constant_1_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Add_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Add_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Sqrt_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Sqrt"
#     op_type: "Sqrt"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Sub_output_0"
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Sqrt_output_0"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Div_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Div"
#     op_type: "Div"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Div_output_0"
#     input: "net.trm_encoder.layer.1.multi_head_attention.LayerNorm.weight"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Mul_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Mul_output_0"
#     input: "net.trm_encoder.layer.1.multi_head_attention.LayerNorm.bias"
#     output: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Add_1_output_0"
#     name: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Add_1"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/multi_head_attention/LayerNorm/Add_1_output_0"
#     input: "onnx::MatMul_400"
#     output: "/net/trm_encoder/layer.1/feed_forward/dense_1/MatMul_output_0"
#     name: "/net/trm_encoder/layer.1/feed_forward/dense_1/MatMul"
#     op_type: "MatMul"
#   }
#   node {
#     input: "net.trm_encoder.layer.1.feed_forward.dense_1.bias"
#     input: "/net/trm_encoder/layer.1/feed_forward/dense_1/MatMul_output_0"
#     output: "/net/trm_encoder/layer.1/feed_forward/dense_1/Add_output_0"
#     name: "/net/trm_encoder/layer.1/feed_forward/dense_1/Add"
#     op_type: "Add"
#   }
#   node {
#     output: "/net/trm_encoder/layer.1/feed_forward/Constant_output_0"
#     name: "/net/trm_encoder/layer.1/feed_forward/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\000\000\000?"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/feed_forward/dense_1/Add_output_0"
#     input: "/net/trm_encoder/layer.1/feed_forward/Constant_output_0"
#     output: "/net/trm_encoder/layer.1/feed_forward/Mul_output_0"
#     name: "/net/trm_encoder/layer.1/feed_forward/Mul"
#     op_type: "Mul"
#   }
#   node {
#     output: "/net/trm_encoder/layer.1/feed_forward/Constant_1_output_0"
#     name: "/net/trm_encoder/layer.1/feed_forward/Constant_1"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\363\004\265?"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/feed_forward/dense_1/Add_output_0"
#     input: "/net/trm_encoder/layer.1/feed_forward/Constant_1_output_0"
#     output: "/net/trm_encoder/layer.1/feed_forward/Div_output_0"
#     name: "/net/trm_encoder/layer.1/feed_forward/Div"
#     op_type: "Div"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/feed_forward/Div_output_0"
#     output: "/net/trm_encoder/layer.1/feed_forward/Erf_output_0"
#     name: "/net/trm_encoder/layer.1/feed_forward/Erf"
#     op_type: "Erf"
#   }
#   node {
#     output: "/net/trm_encoder/layer.1/feed_forward/Constant_2_output_0"
#     name: "/net/trm_encoder/layer.1/feed_forward/Constant_2"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\000\000\200?"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "/net/trm_encoder/layer.1/feed_forward/Erf_output_0"
#     input: "/net/trm_encoder/layer.1/feed_forward/Constant_2_output_0"
#     output: "/net/trm_encoder/layer.1/feed_forward/Add_output_0"
#     name: "/net/trm_encoder/layer.1/feed_forward/Add"
#     op_type: "Add"
#   }
#   node {
#     input: "/net/trm_encoder/layer.1

#   }
#   initializer {
#     dims: 2
#     data_type: 7
#     name: "onnx::Expand_406"
#     raw_data: "\005\000\000\000\000\000\000\000@\000\000\000\000\000\000\000"
#   }
#   input {
#     name: "x"
#     type {
#       tensor_type {
#         elem_type: 7
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 2
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "output"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 5
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   version: 14
# }

# %% [markdown]
# ### Loading the Onnx model
#
# `
# [ONNXRuntimeError] : 9 : NOT_IMPLEMENTED : Could not find an implementation for Trilu(14) node with name '/net/Trilu'
# `

# %%
# When loading neural graph, Onnx will crash with a Trilu Node NOT_IMPLEMENTED error
ort_sess = ort.InferenceSession(bigmodel_onnx_filename, providers=['CPUExecutionProvider'])
key = {'x': x_train.numpy()}
ort_sess.run(None, key)
# Out:
# ---------------------------------------------------------------------------
# NotImplemented                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 # When loading neural graph, Onnx will crash with a Trilu Node NOT_IMPLEMENTED error
# ----> 2 ort_sess = ort.InferenceSession(bigmodel_onnx_filename, providers=['CPUExecutionProvider'])
#       3 key = {'x': x_train.numpy()}
#       4 ort_sess.run(None, key)
#
# File ~/git/pytorch_onnx_error/venv/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:347, in InferenceSession.__init__(self, path_or_bytes, sess_options, providers, provider_options, **kwargs)
#     344 disabled_optimizers = kwargs["disabled_optimizers"] if "disabled_optimizers" in kwargs else None
#     346 try:
# --> 347     self._create_inference_session(providers, provider_options, disabled_optimizers)
#     348 except ValueError:
#     349     if self._enable_fallback:
#
# File ~/git/pytorch_onnx_error/venv/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:395, in InferenceSession._create_inference_session(self, providers, provider_options, disabled_optimizers)
#     392     disabled_optimizers = set(disabled_optimizers)
#     394 # initialize the C++ InferenceSession
# --> 395 sess.initialize_session(providers, provider_options, disabled_optimizers)
#     397 self._sess = sess
#     398 self._sess_options = self._sess.session_options
#
# NotImplemented: [ONNXRuntimeError] : 9 : NOT_IMPLEMENTED : Could not find an implementation for Trilu(14) node with name '/net/Trilu'

# %% [markdown]
# ### Demonstrate that a nested model with torch.tril() working with Onnx

# %%
class SubModel(nn.Module):
    def forward(self, x):
        super(SubModel, self).__init__()
        return torch.tril(x)
    
class TrilModel(nn.Module):
    def __init__(self):
        super(TrilModel, self).__init__()
        self.net = SubModel()
    
    def forward(self, x):
        return self.net.forward(x)

# %%
model2 = TrilModel()
model2.eval()
model2.forward(x_train)
# Out:
# tensor([[1, 0]])

# %%
torch.onnx.export(
    model2,
    x_train,
    'mymodel2.onnx',
    input_names=['x'],
    output_names=['output'],
)

# %%
onnx.load('mymodel2.onnx')
# Out:
# ir_version: 7
# producer_name: "pytorch"
# producer_version: "1.13.1"
# graph {
#   node {
#     output: "/Constant_output_0"
#     name: "/Constant"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 7
#         raw_data: "\000\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "x"
#     input: "/Constant_output_0"
#     output: "output"
#     name: "/Trilu"
#     op_type: "Trilu"
#     attribute {
#       name: "upper"
#       i: 0
#       type: INT
#     }
#   }
#   name: "torch_jit"
#   input {
#     name: "x"
#     type {
#       tensor_type {
#         elem_type: 7
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 2
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "output"
#     type {
#       tensor_type {
#         elem_type: 7
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 2
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   version: 14
# }

# %%
ort_sess = ort.InferenceSession('mymodel2.onnx', providers=['CPUExecutionProvider'])
key = {'x': x_train.numpy()}
ort_sess.run(None, key)
# Out:
# [array([[1, 0]], dtype=int64)]
